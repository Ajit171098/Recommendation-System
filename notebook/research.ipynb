# %%
print("Ok");
# Out:
# Ok

# %%
# %pip install pandas
# %pip install numpy
# Out:
# Looking in indexes: https://pypi.ni.systems
# ...
#      -------------------------------------- 10.0/10.0 MB 502.3 kB/s eta 0:00:00
# ...
#   Using cached https://pypi.ni.systems/packages/packages/81/c4/34e93fe5f5429d7570ec1fa436f1986fb1f00c3e0f43a589fe2bbcd22c3f/pytz-2025.2-py2.py3-none-any.whl (509 kB)
# ...
#      -------------------------------------- 14.0/14.0 MB 640.1 kB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
# Looking in indexes: https://pypi.ni.systems
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install numpy
import pandas as pd
import numpy as np
